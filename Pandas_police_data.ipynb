# %%
import pandas as pd

# %%
police = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\archive (3)\\police.csv")

# %%
police.head(8)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
# 6  2005-04-01     17:30          NaN             M          1969.0
# 7  2005-06-06     13:20          NaN             F          1986.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# 2        33.0       White                        Speeding   Speeding
# 3        19.0       White                Call for Service      Other
# ...

# %%
police.tail(10)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91731  2015-12-31     16:38          NaN             F          1988.0
# 91732  2015-12-31     19:44          NaN             F          1969.0
# 91733  2015-12-31     19:55          NaN             F          1974.0
# 91734  2015-12-31     20:20          NaN             M          1993.0
# 91735  2015-12-31     20:25          NaN             M          1992.0
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91731        27.0       White                        Speeding
# ...

# %%
police.sample()
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 1054  2005-11-06     10:10          NaN             M          1958.0
#
#       driver_age driver_race violation_raw violation  search_conducted  \
# 1054        47.0       White      Speeding  Speeding             False
#
#      search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 1054         NaN     Citation       False      0-15 Min               False

# %%
police.nlargest(5,["driver_age"])
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 71539  2013-09-08     09:50          NaN             F          1914.0
# 75037  2014-02-14     10:21          NaN             M          1920.0
# 76956  2014-04-25     16:40          NaN             M          1924.0
# 74348  2014-01-18     13:07          NaN             F          1925.0
# 9829   2006-09-06     12:15          NaN             M          1918.0
#
#        driver_age driver_race                   violation_raw  \
# 71539        99.0       White         Other Traffic Violation
# 75037        94.0       White         Other Traffic Violation
# 76956        90.0       White                        Speeding
# 74348        89.0       White  Equipment/Inspection Violation
# 9829         88.0       White                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 71539  Moving violation             False         NaN     Citation
# ...

# %%
police.nsmallest(5,["driver_age"])
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 10500  2006-09-30     01:30          NaN             M          1991.0
# 17771  2007-06-11     12:30          NaN             M          1992.0
# 18357  2007-07-04     00:40          NaN             F          1992.0
# 25294  2008-04-21     11:19          NaN             M          1993.0
# 45988  2010-11-10     19:39          NaN             F          1995.0
#
#        driver_age driver_race            violation_raw         violation  \
# 10500        15.0       Black  Other Traffic Violation  Moving violation
# 17771        15.0       White                 Speeding          Speeding
# 18357        15.0       White  Other Traffic Violation  Moving violation
# 25294        15.0    Hispanic  Other Traffic Violation  Moving violation
# 45988        15.0       White  Other Traffic Violation  Moving violation
#
#        search_conducted         search_type   stop_outcome is_arrested  \
# ...

# %%
police.drop_duplicates("driver_race")
# Out:
#       stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0    2005-01-02     01:55          NaN             M          1985.0
# 5    2005-03-23     09:45          NaN             M          1982.0
# 10   2005-07-13     16:20          NaN             M          1979.0
# 25   2005-09-03     16:02          NaN           NaN             NaN
# 42   2005-10-01     00:50          NaN             M          1977.0
# 128  2005-10-04     14:12          NaN             M          1976.0
#
#      driver_age driver_race                   violation_raw         violation  \
# 0          20.0       White                        Speeding          Speeding
# 5          23.0       Black  Equipment/Inspection Violation         Equipment
# 10         26.0       Asian                        Speeding          Speeding
# 25          NaN         NaN                             NaN               NaN
# 42         28.0    Hispanic         Other Traffic Violation  Moving violation
# ...
