# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\archive (3)\\police.csv")

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df.head()

# %%
df.tail(2)

# %%
df.index

# %%
df.columns

# %%
df.shape

# %%
df.describe()

# %%
df[-6:-1:1]

# %%
df.to_numpy()

# %%
df.sort_index(axis=1,ascending=False)

# %%
df

# %%
ef = df.drop(["search_type"],axis=1)
ef

# %%
df.drop([91740],axis=0)

# %%
df.drop(["search_type"],axis=1)

# %%
df.loc[[2,3],"driver_age_raw"]

# %%
df.iloc[2]

# %%
df.dropna()

# %%
tf = df.dropna(axis=1)
tf

# %%
tf.isnull().sum()

# %%
tf.isnull()

# %%
defr = df.fillna(0)

# %%
defr.isnull().sum()

# %%
df.isnull().sum()

# %%
defr

# %%
df.transpose()
# Out:
#                          0           1           2                 3      \
# stop_date           2005-01-02  2005-01-18  2005-01-23        2005-02-20
# stop_time                01:55       08:15       23:15             17:15
# county_name                NaN         NaN         NaN               NaN
# driver_gender                M           M           M                 M
# driver_age_raw          1985.0      1965.0      1972.0            1986.0
# driver_age                20.0        40.0        33.0              19.0
# driver_race              White       White       White             White
# violation_raw         Speeding    Speeding    Speeding  Call for Service
# violation             Speeding    Speeding    Speeding             Other
# search_conducted         False       False       False             False
# search_type                NaN         NaN         NaN               NaN
# stop_outcome          Citation    Citation    Citation     Arrest Driver
# ...
